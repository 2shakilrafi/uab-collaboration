# %%
import pyreadstat
import pandas as pd

# %%
meals = ["breakfast", "lunch", "dinner", "snack", "drink"]

for meal in meals:
    pd.read_csv(meal+".csv")

# %%
pd.read_csv("lunch.csv")
# Out:
#       Unnamed: 0   SID   DayName NewDayName  DayNumber      MealName  \
# 0              0  1101   1.25.19   01.25.19          1  School Lunch
# 1              1  1101   1.25.19   01.25.19          1  School Lunch
# 2              2  1101   1.25.19   01.25.19          1  School Lunch
# 3              3  1101   1.25.19   01.25.19          1  School Lunch
# 4              4  1103   1.25.19   01.25.19          1  School Lunch
# ...          ...   ...       ...        ...        ...           ...
# 6061        6061  2519  11.21.19   11.21.19          7         Lunch
# 6062        6062  2519  11.21.19   11.21.19          7         Lunch
# 6063        6063  2521  11.21.19   11.21.19          7         Lunch
# 6064        6064  2521  11.21.19   11.21.19          7         Lunch
# 6065        6065  2521  11.21.19   11.21.19          7         Lunch
#
#       MealName_A                                           FoodName   Group1  \
# ...

# %%
pd.read_csv("w1-census-block.csv")
# Out:
#      Unnamed: 0     SID  Address_Exclude  Total_Population  \
# 0             0  2308.0              0.0            2125.0
# 1             1  2311.0              0.0            2125.0
# 2             2  2313.0              0.0            2125.0
# 3             3  2315.0              0.0            2125.0
# 4             4  2316.0              0.0            2125.0
# ..          ...     ...              ...               ...
# 284         284  1104.0              0.0            6308.0
# 285         285  1108.0              0.0            6308.0
# 286         286  1109.0              0.0            6308.0
# 287         287  1810.0              0.0            6308.0
# 288         288  1815.0              0.0            6308.0
#
#      Total_Housing_Units  Median_Household_Income_InflationAdjusted  \
# 0                  785.0                                    52303.0
# 1                  785.0                                    52303.0
# ...

# %%
data = pd.read_csv("metadata.txt", delimiter="\t")

# %%
data
# Out:
#     Sample_ID   SID  reads_sample  site  female  W1incimp  p1edu1  p1edu2  \
# 0     W1x1102  1102         42258     1       1       6.0       1       1
# 1     W1x1103  1103         45957     1       0      13.0       2       2
# 2     W1x1104  1104          4087     1       0       1.0       6       5
# 3     W1x1106  1106         44104     1       0       6.0       2       2
# 4     W1x1110  1110         35098     1       0       3.0       1       1
# ..        ...   ...           ...   ...     ...       ...     ...     ...
# 132   W1x2508  2508         61771    15       0      13.0       7       6
# 133   W1x2513  2513         47269    15       1      13.0       6       5
# 134   W1x2514  2514         54806    15       1      13.0       3       3
# 135   W1x2515  2515         60982    15       1      13.0       6       5
# 136   W1x2516  2516         60699    15       0      13.0       3       3
#
#           SES  singlepar  ...  Actinobacteriota_ra  Unnamed: 54  Unnamed: 55  \
# ...

# %%
data.to_csv("metadata.csv")
